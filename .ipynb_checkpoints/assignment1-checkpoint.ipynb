# %%
import json

# %%
import json

with open("storedata.json", "r") as f:
    data = json.load(f)

print(data)
# Out:
# [{'id': 1, 'customer_name': 'Alice', 'rating': 5, 'feedback': 'Excellent service and fast delivery.', 'product': 'Laptop', 'date': '2026-08-01'}, {'id': 2, 'customer_name': 'Bob', 'rating': 4, 'feedback': 'Product quality is good.', 'product': 'Mouse', 'date': '2026-08-02'}]

# %%
data=load_data("storedata.json")
print(type(data))
# Out:
# <class 'list'>
